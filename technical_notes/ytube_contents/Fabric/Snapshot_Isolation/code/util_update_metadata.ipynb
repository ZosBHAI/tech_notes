# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, 358063bf-b7cc-4173-bc34-78b6f1f9d207, 3, Finished, Available, Finished)

# %%
# %run util_retry_update_warehouse
# Out:
# StatementMeta(, 358063bf-b7cc-4173-bc34-78b6f1f9d207, 9, Finished, Available, Finished)

# %%
# retryable_update(
#     run_id=101,
#     task_ids=10,
#     status="FAILED",
#     task_error_message="Schema extraction failed"
# )
# Out:
# StatementMeta(, 358063bf-b7cc-4173-bc34-78b6f1f9d207, 10, Finished, Available, Finished)

# %%
# run_id = 101
# task_id=10
# status = "FAILED"
# msg="Schema extraction failed"
# Out:
# StatementMeta(, 358063bf-b7cc-4173-bc34-78b6f1f9d207, 11, Finished, Available, Finished)

# %%
retryable_update(
    run_id=run_id,
    task_ids=task_id,
    status=status,
    task_error_message=msg
)
# Out:
# StatementMeta(, 358063bf-b7cc-4173-bc34-78b6f1f9d207, 12, Finished, Available, Finished)
# Generated SQL:
#         UPDATE dbo.ETL_TASK_EXECUTION_LOG
#         SET END_TIME = CURRENT_TIMESTAMP,
#             STATUS = 'FAILED',
#             TASK_ERROR_MESSAGE = 'Schema extraction failed'
#         WHERE INSTANCE_ID = 101
#         AND TASK_ID IN (10)
#
# Statement executed successfully. Rows affected: 0
# SQL executed successfully:
#         UPDATE dbo.ETL_TASK_EXECUTION_LOG
#         SET END_TIME = CURRENT_TIMESTAMP,
#             STATUS = 'FAILED',
#             TASK_ERROR_MESSAGE = 'Schema extraction failed'
#         WHERE INSTANCE_ID = 101
#         AND TASK_ID IN (10)
#
# Updated task execution log for Run ID 101, Task(s) [10].
