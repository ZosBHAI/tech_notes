# %%
DAG = {
    "activities": [
        {
            "name": "Update_Metadata_Task1",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 1,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
        },
        {
            "name": "Update_Metadata_Task2",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 2,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
        },
        {
            "name": "Update_Metadata_Task3",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 3,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            },
            "retry": 1,
            "retryIntervalInSeconds": 10
            
        },
        {
            "name": "Update_Metadata_Task4",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 4,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
            
        },
          {
            "name": "Update_Metadata_Task5",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 5,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
        },
        {
            "name": "Update_Metadata_Task6",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 6,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
        },
        {
            "name": "Update_Metadata_Task7",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 7,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            },
            "retry": 1,
            "retryIntervalInSeconds": 10
            
        },
        {
            "name": "Update_Metadata_Task8",
            "path": "util_update_metadata",
            "timeoutPerCellInSeconds": 90,
            "args": {
                "run_id": 1001,
                "task_id": 8,
                "status": "FAILED",
                "msg": "Schema extraction failed"
            }
            
        }
    ],
    "timeoutInSeconds": 43200,
    "concurrency": 4
}
mssparkutils.notebook.runMultiple(DAG, {"displayDAGViaGraphviz": False})
# Out:
# StatementMeta(, 46d94417-d948-4a4d-a3f5-9b79233c2094, 6, Finished, Available, Finished)
# {'Update_Metadata_Task1': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task2': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task3': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task4': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task5': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task6': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task7': {'exitVal': '', 'exception': None},
#  'Update_Metadata_Task8': {'exitVal': '', 'exception': None}}
